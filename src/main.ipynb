# %% [markdown]
# # Homework
#
# This notebook shows completed homework submission. It is organized in the format:
#
# - Task: Homework task
# - Tools: Tools used during the task
# - Observations:
# - Screenshots
#
# `Screenshots` will be saved in the [screenshots](./screenshots/) folder.
#
# ---

# %% [markdown]
# ## Task 1: Brave Search
#
# ### Description
#
# The goal is to use the brave search tool via claude to search for “latest AI paper publication platforms”.
#
# #### Prompt
#
# `Use Brave Search to look up the latest AI paper publication platforms and return the top 3 results with title and link.`
#
# ### Tools & Resources
#
# - [Brave Search Tool](https://github.com/modelcontextprotocol/servers-archived/tree/main/src/brave-search)
# - [Claude Desktop](https://www.claude.com/download)
# - [Brave Search API](https://brave.com/search/api/)
#
#
# ### Observations
#
# The brave search tool pulled 10 results but the large language model controlled the output and returned 3 results as requested by the `prompt`.
#
# ### Screenshots
#
# - Results
#
# ![Claude Desktop screenshot](./screenshots/brave-search-mcp-result.png)
#
#
# ---

# %% [markdown]
# ## Task 2: GitHub
#
# ### Description
#
# The goal is to use the github mcp server together with claude desktop to access my git hub repository and list the most recent 5 commits.
#
# #### Prompt
#
# `Connect to my GitHub account using the MCP plugin and list the 5 latest commits from the repository my-cool-project.`
#
# ### Tools & Resources
#
# - [Claude Desktop](https://www.claude.com/download)
# - [GitHub Mcp server](https://github.com/modelcontextprotocol/servers/blob/main/src/git)
#
#
# ### Observations
#
# The git tool was able to list the repositories int the format
#
# ``` txt
# 5. JSON output format refactor
#     SHA: 69371f4
#     Date: October 18, 2025
#     Message: Refactor resume critique functionality to enforce JSON output format. Removed Pydantic schema and updated critique prompt for clarity. Improved error handling for JSON parsing and response formatting.
#     Link: View commit
# ```
#
# ### Screenshots
#
# - Results
#
# ![Claude Desktop screenshot](./screenshots/git-tool-search-mcp-result.png)
#
#
# ---

# %% [markdown]
# ## Task 3: Puppeteer
#
# ### Description
#
# The goal is to use Puppeteer to visit a website and take screenshots.
#
# #### Prompt
#
# `Use Puppeteer to go to https://www.inference.ai/ and capture a full-page screenshot saved as example.png.`
#
# ### Tools & Resources
#
# - [Claude Desktop](https://www.claude.com/download)
# - [Puppeteer Mcp server](https://github.com/modelcontextprotocol/servers-archived/tree/main/src/puppeteer)
#
#
# ### Observations
#
# The puppeteer tool opened the webpage and took a screenshot as requested.
#
# ### Screenshots
#
# - Results (claude output)
#
# ![Claude Desktop screenshot](./screenshots/puppeteer-search-mcp-result.png)
#
# - Results (screenshot)
#
# ![Claude Desktop screenshot](./screenshots/screenshot-result.png)
#
#
# ---

# %% [markdown]
# ## Task 4: File system
#
# ### Description
#
# The goal is to use file system tool to create files on the allowed folder.
#
# #### Prompt
#
# `Use Filesystem to create a folder named mcp_test and add a file hello.txt inside with the text 'Hello MCP!'.`
#
# ### Tools & Resources
#
# - [Claude Desktop](https://www.claude.com/download)
# - [FileSystem Mcp server](https://github.com/modelcontextprotocol/servers/tree/main/src/filesystem)
#
#
# ### Observations
#
# [File](./mcp-access/mcp_test/hello.txt) was created with the contents.
#
# ### Screenshots
#
# - Results (claude output 1)
#
# ![Claude Desktop screenshot](./screenshots/filesystem-mcp-result.png)
#
# - Results - File folder
#
# ![Claude Desktop screenshot](./screenshots/filesystem-mcp-result-example.png)
#
# ---

# %% [markdown]
# ## Task 5: Sequential Thinking
#
# ### Description
#
# The goal is to use the sequential thinking tool to ask a question about technical interview preparation.
#
# #### Prompt
#
# `Use Sequential Thinking to create a step-by-step plan for preparing for a technical interview.`
#
# ### Tools & Resources
#
# - [Claude Desktop](https://www.claude.com/download)
# - [Sequential thinking Mcp server](https://github.com/modelcontextprotocol/servers/tree/main/src/sequentialthinking)
#
#
# ### Observations
#
# Result: An eleven step guide to preparing  for a technical interview.
#
# ### Screenshots
#
# - Results (claude output 1)
#
# ![Claude Desktop screenshot](./screenshots/sequential-thinking-mcp-result.png)
#
#
# ---

# %% [markdown]
# ## Task 6: Notion
#
# ### Description
#
# The goal is to use the notion tool to document the list of activities completed.
#
# #### Prompt
#
# `Use the Notion plugin to create a new page titled 'MCP Automation Test' and write a summary of the tasks I just completed using each plugin.`
#
# ### Tools & Resources
#
# - [Claude Desktop](https://www.claude.com/download)
# - [Sequential thinking Mcp server](https://github.com/makenotion/notion-mcp-server#readme)
#
# ### Observations
#
# Result: A notion document!
#
# [The notion document](https://www.notion.so/MCP-Automation-Test-29ad07b8c28181d686c3e4c687e43ffc?source=copy_link) creatad for the exercise.
#
# ### Screenshots
#
# - Results (claude output 1)
#
# ![Claude Desktop screenshot](./screenshots/notion-mcp-result.png)
#
#
# ---

# %% [markdown]
# # Advanced Task
#
# Workflow: visit webpage (puppeteer) -> scrape content (puppeteer) -> save localy  (file system) -> save to notion and generate documentation (summary)
#
# ### Prompt
#
# ``` text
# Please execute the following workflow using available tools:
#
#     1. Visit webpage: Navigate to https://travel.state.gov/content/travel/en/News/visas-news.html using Puppeteer.
#
#     2. Scrape content: Extract all relevant textual content from the page, including headlines, article summaries, and publication dates.
#
#     3. Save locally: Store the scraped content as a .txt or .md file in the local file system with a filename like visas-news-{date}.md.
#
#     4. Save to Notion: Push the scraped content into a Notion database or page titled “Visa News Digest” with today’s date as the entry title.
#
#     5. Generate documentation: Summarize the scraped content into a concise digest (3–5 bullet points) highlighting key updates or announcements. Include this summary both in the local file and the Notion entry.
#
# ```
#
# ### Results
#
# - [Notion Page](https://www.notion.so/Visa-News-Digest-October-28-2025-29ad07b8c281816cb1eced4822b3a9c3?source=copy_link)
# - [File Created](./mcp-access/visas-news-2025-10-28.md)
#
# ### Screenshots
#
# - Results (claude output 1)
#
# ![Claude Desktop screenshot](./screenshots/advanced-model-command-pipeline-result.png)
