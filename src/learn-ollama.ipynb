# %%
# static model
from langchain.agents import create_agent
from tools import example

tools=[example.say_hello]

agent = create_agent(
    model="ollama:smollm2:1.7b",
    tools=tools
)

print("Hello")
# Out:
# Hello
